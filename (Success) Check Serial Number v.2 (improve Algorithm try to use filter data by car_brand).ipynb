# %%
import pandas as pd

# %%
All_product = pd.read_excel('AllProduct.xlsx', header = 1)
autopair_rev = pd.read_excel('autopair_rev16.01_v2.xlsx', header = 1)

# %%
All_product['index'] = range(1, len(All_product) + 1)
All_product = All_product.set_index('index')
All_product
# Out:
#          serialNo   Supplier_NO.        OEM_NO. Benchmark_NO. car_brand  \
# index
# 1      IC-0000001            NaN            NaN           NaN      AUDI
# 2      DD-0000112            NaN            NaN           NaN    TOYOTA
# 3      IC-0000002            NaN            NaN           NaN       BMW
# 4      DI-0000080            NaN            NaN           NaN    TOYOTA
# 5      IC-0000003            NaN            NaN           NaN       BMW
# ...           ...            ...            ...           ...       ...
# 45833  AH-0000231            NaN            NaN           NaN     MAZDA
# 45834  IG-0000252  8-98036-321-0  8-98036-321-0           NaN     ISUZU
# 45835  AD-0000026         DB7042            NaN           NaN     ISUZU
# 45836  AC-0000411         DF7462            NaN           NaN     ISUZU
# 45837  EB-0100093            NaN    16572-0H040           NaN    TOYOTA
#
#       car_model model_name_th                           nickname Transmission  \
# index
# ...

# %%
autopair_rev['index'] = range(1, len(autopair_rev) + 1)
autopair_rev = autopair_rev.set_index('index')
autopair_rev
# Out:
#          serialNo   Supplier_NO.        OEM_NO. Benchmark_NO. car_brand  \
# index
# 1      IC-0000001            NaN            NaN           NaN      AUDI
# 2      DD-0000112            NaN            NaN           NaN    TOYOTA
# 3      IC-0000002            NaN            NaN           NaN       BMW
# 4      DI-0000080            NaN            NaN           NaN    TOYOTA
# 5      IC-0000003            NaN            NaN           NaN       BMW
# ...           ...            ...            ...           ...       ...
# 46198         NaN            NaN            NaN           NaN     MAZDA
# 46199         NaN  8-98036-321-0  8-98036-321-0           NaN     ISUZU
# 46200         NaN         DB7042            NaN           NaN     ISUZU
# 46201         NaN         DF7462            NaN           NaN     ISUZU
# 46202         NaN            NaN    16572-0H040           NaN    TOYOTA
#
#       car_model model_name_th                           nickname Transmission  \
# index
# ...

# %%
# autopair_rev['CC'].iloc[12498:12504]

# %%
# All_product['CC'].iloc[12469:12475]

# %%
All_product['Merge columns'] = All_product[All_product.columns[1:18]].apply(lambda x: ','.join(x.dropna().astype(str)),axis=1)
All_product
# Out:
#          serialNo   Supplier_NO.        OEM_NO. Benchmark_NO. car_brand  \
# index
# 1      IC-0000001            NaN            NaN           NaN      AUDI
# 2      DD-0000112            NaN            NaN           NaN    TOYOTA
# 3      IC-0000002            NaN            NaN           NaN       BMW
# 4      DI-0000080            NaN            NaN           NaN    TOYOTA
# 5      IC-0000003            NaN            NaN           NaN       BMW
# ...           ...            ...            ...           ...       ...
# 45833  AH-0000231            NaN            NaN           NaN     MAZDA
# 45834  IG-0000252  8-98036-321-0  8-98036-321-0           NaN     ISUZU
# 45835  AD-0000026         DB7042            NaN           NaN     ISUZU
# 45836  AC-0000411         DF7462            NaN           NaN     ISUZU
# 45837  EB-0100093            NaN    16572-0H040           NaN    TOYOTA
#
#       car_model model_name_th                           nickname Transmission  \
# index
# ...

# %%
allproduct = All_product.iloc[:,88:89].astype(str)
allproduct
# Out:
#                                            Merge columns
# index
# 1      AUDI,Q5,คิว5,โฉมปี 2008-2016,ไส้กรองน้ำมันเครื...
# 2      TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),เบ...
# 3      BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2003-2010 (E60),ไส...
# 4      TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),ยา...
# 5      BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2010-2017 (F10),ไส...
# ...                                                  ...
# 45833  MAZDA,MAZDA2,มาสด้า2,โฉมปี 2007-2014 (DY),ลูกส...
# 45834  8-98036-321-0,8-98036-321-0,ISUZU,D-MAX,ดี-แม็...
# 45835   DB7042,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 ...
# 45836  DF7462,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 (...
# 45837  16572-0H040,TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-200...
#
# [45837 rows x 1 columns]

# %%
autopair_rev['Merge columns'] = autopair_rev[autopair_rev.columns[1:18]].apply(lambda x: ','.join(x.dropna().astype(str)),axis=1)
autopair_rev
# Out:
#          serialNo   Supplier_NO.        OEM_NO. Benchmark_NO. car_brand  \
# index
# 1      IC-0000001            NaN            NaN           NaN      AUDI
# 2      DD-0000112            NaN            NaN           NaN    TOYOTA
# 3      IC-0000002            NaN            NaN           NaN       BMW
# 4      DI-0000080            NaN            NaN           NaN    TOYOTA
# 5      IC-0000003            NaN            NaN           NaN       BMW
# ...           ...            ...            ...           ...       ...
# 46198         NaN            NaN            NaN           NaN     MAZDA
# 46199         NaN  8-98036-321-0  8-98036-321-0           NaN     ISUZU
# 46200         NaN         DB7042            NaN           NaN     ISUZU
# 46201         NaN         DF7462            NaN           NaN     ISUZU
# 46202         NaN            NaN    16572-0H040           NaN    TOYOTA
#
#       car_model model_name_th                           nickname Transmission  \
# index
# ...

# %%
allproduct_serial = All_product.iloc[:,0:1].astype(str)
allproduct_serial
# Out:
#          serialNo
# index
# 1      IC-0000001
# 2      DD-0000112
# 3      IC-0000002
# 4      DI-0000080
# 5      IC-0000003
# ...           ...
# 45833  AH-0000231
# 45834  IG-0000252
# 45835  AD-0000026
# 45836  AC-0000411
# 45837  EB-0100093
#
# [45837 rows x 1 columns]

# %%
allproduct_brand = All_product.iloc[:,4:5].astype(str)
allproduct_brand
# Out:
#       car_brand
# index
# 1          AUDI
# 2        TOYOTA
# 3           BMW
# 4        TOYOTA
# 5           BMW
# ...         ...
# 45833     MAZDA
# 45834     ISUZU
# 45835     ISUZU
# 45836     ISUZU
# 45837    TOYOTA
#
# [45837 rows x 1 columns]

# %%
autopairrev = autopair_rev.iloc[:,94:95].astype(str)
# autopairrev = autopair_rev.iloc[0:5,95:96].astype(str)
autopairrev = autopairrev.rename({'Merge columns': 'Merge_columns'}, axis=1)
autopairrev
# Out:
#                                            Merge_columns
# index
# 1      AUDI,Q5,คิว5,โฉมปี 2008-2016,ไส้กรองน้ำมันเครื...
# 2      TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),เบ...
# 3      BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2003-2010 (E60),ไส...
# 4      TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),ยา...
# 5      BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2010-2017 (F10),ไส...
# ...                                                  ...
# 46198  MAZDA,MAZDA2,มาสด้า2,โฉมปี 2007-2014 (DY),ลูกส...
# 46199  8-98036-321-0,8-98036-321-0,ISUZU,D-MAX,ดี-แม็...
# 46200   DB7042,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 ...
# 46201  DF7462,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 (...
# 46202  16572-0H040,TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-200...
#
# [46202 rows x 1 columns]

# %%
all_product = pd.concat([allproduct_serial,allproduct_brand,allproduct], axis=1)
# all_product = all_product.iloc[12469:12474,:]
# all_product = all_product.iloc[0:5,:]
all_product
# Out:
#          serialNo car_brand                                      Merge columns
# index
# 1      IC-0000001      AUDI  AUDI,Q5,คิว5,โฉมปี 2008-2016,ไส้กรองน้ำมันเครื...
# 2      DD-0000112    TOYOTA  TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),เบ...
# 3      IC-0000002       BMW  BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2003-2010 (E60),ไส...
# 4      DI-0000080    TOYOTA  TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),ยา...
# 5      IC-0000003       BMW  BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2010-2017 (F10),ไส...
# ...           ...       ...                                                ...
# 45833  AH-0000231     MAZDA  MAZDA,MAZDA2,มาสด้า2,โฉมปี 2007-2014 (DY),ลูกส...
# 45834  IG-0000252     ISUZU  8-98036-321-0,8-98036-321-0,ISUZU,D-MAX,ดี-แม็...
# 45835  AD-0000026     ISUZU   DB7042,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 ...
# 45836  AC-0000411     ISUZU  DF7462,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 (...
# 45837  EB-0100093    TOYOTA  16572-0H040,TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-200...
#
# ...

# %%
rowA = []
for idx_row, row in all_product.iterrows():
    merge_data = row['Merge columns']
    serial = row['serialNo']
    brand = row['car_brand']
    auto_pairrev = autopairrev[autopairrev.Merge_columns.str.contains(brand)]
#     print(idx_row, merge_data)
    pair = []
    pairr = []
    for idx, i in auto_pairrev.iterrows():
        auto_rev = i['Merge_columns']
#         print(idx, auto_rev)
        if auto_rev == merge_data:
            pair.append(idx+2)
            pair.append(serial)
            pair.append(auto_rev)
            pair.append(merge_data)
#             merge_data.append(roww)
        else:
            pairr.append(False)
#         print(pair)
    rowA.append(pair)
# print(rowA)
df = pd.DataFrame(rowA, columns = ['index', 'Serial_No', 'autopair_rev', 'all_product'])
df
#     check = autopair[pair]
# check2 = any(k == True for k in check)

    
#     data = autopair
#     if check:
#         check2 = data[pair]
#         row.append(check2)
#         roww.append (serial)
#     else:
#         check2 = "NA"

# dfA = pd.DataFrame(roww, columns = ['Serial_No'])
# dfB = pd.DataFrame(row, columns = ['Data'])
# df = pd.concat([dfA,dfB], axis=1)
# df['index'] = range(1, len(df) + 1)
# df = df.set_index('index')
# df
# Out:
#          index   Serial_No                                       autopair_rev  \
# 0          3.0  IC-0000001  AUDI,Q5,คิว5,โฉมปี 2008-2016,ไส้กรองน้ำมันเครื...
# 1          4.0  DD-0000112  TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),เบ...
# 2          5.0  IC-0000002  BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2003-2010 (E60),ไส...
# 3          6.0  DI-0000080  TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-2006 (ACV30),ยา...
# 4          7.0  IC-0000003  BMW,SERIES 5,ซีรี่ย์5,โฉมปี 2010-2017 (F10),ไส...
# ...        ...         ...                                                ...
# 45832  46200.0  AH-0000231  MAZDA,MAZDA2,มาสด้า2,โฉมปี 2007-2014 (DY),ลูกส...
# 45833  46201.0  IG-0000252  8-98036-321-0,8-98036-321-0,ISUZU,D-MAX,ดี-แม็...
# 45834  46202.0  AD-0000026   DB7042,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 ...
# 45835  46203.0  AC-0000411  DF7462,ISUZU,D-MAX,ดี-แม็กซ์,โฉมปี 2002-2011 (...
# 45836  46204.0  EB-0100093  16572-0H040,TOYOTA,CAMRY,คัมรี่,โฉมปี 2002-200...
#
# ...

# %%
df.to_excel('check_serial_number_v.4.xlsx', index=False)
